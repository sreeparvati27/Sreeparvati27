# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats 
file_path = r"C:\Users\Dell\Desktop\studentdata.csv.xlsx"
df = pd.read_excel(file_path)
df.head(20)
# Out:
#     Math_Score  Reading_Score   Writing_Score   Placement_Score
# 0           44              90              52                78
# 1           40             100              61               100
# 2           74              53              57                72
# 3           55              45              51                83
# 4           64              46              66                85
# 5           80              69              55                75
# 6           45              88              50                94
# 7           52              89              57                99
# 8           55              86              59                84
# 9           77              87              59                84
# 10          52              60              63                79
# 11          77              40              52                90
# 12          43              93              69                73
# 13          58              61              61                93
# 14          74              75              68                83
# 15          80              69              59                99
# 16          65              68              52                92
# 17          48              56              61                70
# 18          74              41              60                83
# 19          43              91              60                71

# %%
df.isnull()
# Out:
#     Math_Score  Reading_Score   Writing_Score   Placement_Score
# 0        False           False           False             False
# 1        False           False           False             False
# 2        False           False           False             False
# 3        False           False           False             False
# 4        False           False           False             False
# ..         ...             ...             ...               ...
# 74       False           False           False             False
# 75       False           False           False             False
# 76       False           False           False             False
# 77       False           False           False             False
# 78       False           False           False             False
#
# [79 rows x 4 columns]

# %%
print(df.columns)
# Out:
# Index(['Math_Score', 'Reading_Score ', 'Writing_Score ', 'Placement_Score '], dtype='object')

# %%
series1 = pd.notnull(df["Reading_Score "]) 
df[series1]
# Out:
#     Math_Score  Reading_Score   Writing_Score   Placement_Score
# 0           44              90              52                78
# 1           40             100              61               100
# 2           74              53              57                72
# 3           55              45              51                83
# 4           64              46              66                85
# ..         ...             ...             ...               ...
# 74          63              36              60                86
# 75          49              47              64                95
# 76          66              40              55                77
# 77          52              70              68                87
# 78          50              64              58               100
#
# [79 rows x 4 columns]

# %%
ndf=df 
ndf.fillna(0)
# Out:
#     Math_Score  Reading_Score   Writing_Score   Placement_Score
# 0           44              90              52                78
# 1           40             100              61               100
# 2           74              53              57                72
# 3           55              45              51                83
# 4           64              46              66                85
# ..         ...             ...             ...               ...
# 74          63              36              60                86
# 75          49              47              64                95
# 76          66              40              55                77
# 77          52              70              68                87
# 78          50              64              58               100
#
# [79 rows x 4 columns]

# %%
m_v=df['Reading_Score '].mean()
df['Reading_Score '].fillna(value=m_v, inplace=True)
df
# Out:
#     Math_Score  Reading_Score   Writing_Score   Placement_Score
# 0           44              90              52                78
# 1           40             100              61               100
# 2           74              53              57                72
# 3           55              45              51                83
# 4           64              46              66                85
# ..         ...             ...             ...               ...
# 74          63              36              60                86
# 75          49              47              64                95
# 76          66              40              55                77
# 77          52              70              68                87
# 78          50              64              58               100
#
# [79 rows x 4 columns]

# %%
ndf.dropna(how = 'all')
# Out:
#     Math_Score  Reading_Score   Writing_Score   Placement_Score
# 0           44              90              52                78
# 1           40             100              61               100
# 2           74              53              57                72
# 3           55              45              51                83
# 4           64              46              66                85
# ..         ...             ...             ...               ...
# 74          63              36              60                86
# 75          49              47              64                95
# 76          66              40              55                77
# 77          52              70              68                87
# 78          50              64              58               100
#
# [79 rows x 4 columns]

# %%
ndf.dropna(axis = 1)
# Out:
#     Math_Score  Reading_Score   Writing_Score   Placement_Score
# 0           44              90              52                78
# 1           40             100              61               100
# 2           74              53              57                72
# 3           55              45              51                83
# 4           64              46              66                85
# ..         ...             ...             ...               ...
# 74          63              36              60                86
# 75          49              47              64                95
# 76          66              40              55                77
# 77          52              70              68                87
# 78          50              64              58               100
#
# [79 rows x 4 columns]

# %%
new_data =ndf.dropna (axis = 0, how ='any') 
new_data
# Out:
#     Math_Score  Reading_Score   Writing_Score   Placement_Score
# 0           44              90              52                78
# 1           40             100              61               100
# 2           74              53              57                72
# 3           55              45              51                83
# 4           64              46              66                85
# ..         ...             ...             ...               ...
# 74          63              36              60                86
# 75          49              47              64                95
# 76          66              40              55                77
# 77          52              70              68                87
# 78          50              64              58               100
#
# [79 rows x 4 columns]

# %%
col =['Reading_Score ', 'Reading_Score ', 'Writing_Score '] 
df.boxplot(col)
# Out:
# <AxesSubplot:>
